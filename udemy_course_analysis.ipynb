# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sb

# %%
data=pd.read_csv('udemy_courses.csv')

# %%
data.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %% [markdown]
# # Minimum,Maximum,Average Course Duration

# %%
avg_dur=data['content_duration'].mean()
max_dur=data['content_duration'].max()
min_dur=data['content_duration'].min()
data_min_dur=data.loc[data['content_duration']==min_dur]
data_max_dur=data.loc[data['content_duration']==max_dur]
course_min_dur=data_min_dur['course_title']
course_max_dur=data_max_dur['course_title']
print_data=f'Average Duration :{avg_dur}\nMaximum Duration :{max_dur}({course_max_dur})\nMinimum Duration :{min_dur}({course_min_dur})'
print(print_data)
# Out:
# Average Duration :4.094516947616459
# Maximum Duration :78.5(1658    The Complete Figure Drawing Course HD
# Name: course_title, dtype: object)
# Minimum Duration :0.0(892    Mutual Funds for Investors in Retirement Accounts
# Name: course_title, dtype: object)

# %% [markdown]
# # Which  Subject Highest reviews

# %%
sb.relplot(x='subject',y='num_reviews',kind="line",data=data)

# %% [markdown]
# Answer : Web Development

# %% [markdown]
# # Which Level of Highest and Lowest Subscribers

# %%
sb.relplot(x="level", y="num_subscribers", hue="level",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=data)

# %% [markdown]
# Answer: Highest -Begginer Level
#         lowest - Expert Level

# %% [markdown]
# # Which Subject of Max price in which Level

# %%
sb.set(style="darkgrid", color_codes=True)
sb.stripplot(x="subject", y="price", hue='level',
              data=data, dodge=True, alpha=.25, zorder=1)

# %% [markdown]
# Answer: web development in Begginner level

# %% [markdown]
# # Sort the table In increasing order of price

# %%
data.sort_values(['price'])
# Out:
#       course_id                                       course_title  \
# 1369     874656   Create Stunning Infographics to Share your Ideas
# 433      199822      IAS 12 - Accounting for Income Taxes (Basics)
# 432      830870     Forex Trading For Beginners: Technical Trading
# 966      662996  The Tax Advantaged Investor: A Guide to Legal ...
# 3297     563668  Learn how to create a WordPress theme using Pi...
# ...         ...                                                ...
# 3233     446134  Ultimate Web Designer & Developer Course: Buil...
# 3232     764164              The Complete Web Developer Course 2.0
# 1136     645634  How to Build Profitable FOREX Automated Tradin...
# 888     1083744  How to Invest Using ETFs from Former Wall Stre...
# 0       1070968                 Ultimate Investment Banking Course
#
#                                                     url  is_paid  price  \
# 1369                 https://www.udemy.com/infographic/    False      0
# ...
